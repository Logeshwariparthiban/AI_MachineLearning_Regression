# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(independent, dependent, test_size=0.30,random_state=0)

# %%
 from sklearn.model_selection import GridSearchCV
 from sklearn.tree import DecisionTreeRegressor
 param_grid = {'criterion':['absolute_error', 'poisson', 'squared_error', 'friedman_mse'],
 'max_features': ['sqrt','log2'],
 'splitter':['best','random']}
grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit = True, verbose= 3,n_jobs=-1)
 # fitting the model for grid search
 grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['absolute_error', 'poisson',
#                                        'squared_error', 'friedman_mse'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re=grid.cv_results_
grid_predictions = grid.predict(X_test)

# %%
from sklearn.metrics import r2_score
r_score=r2_score(y_test,grid_predictions)
print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter {'criterion': 'squared_error', 'max_features': 'sqrt', 'splitter': 'best'}: 0.6615952564729957

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.019688      0.004737         0.004910        0.001813
# 1        0.015612      0.003688         0.003004        0.002585
# 2        0.013443      0.002298         0.003614        0.002769
# 3        0.012440      0.003874         0.001680        0.001444
# 4        0.007036      0.002093         0.003196        0.001873
# 5        0.006194      0.002171         0.003365        0.002731
# 6        0.007975      0.003665         0.003207        0.002692
# 7        0.004257      0.005370         0.007193        0.003106
# 8        0.003295      0.002584         0.003111        0.003115
# 9        0.004954      0.003244         0.002536        0.002885
# 10       0.002464      0.002740         0.003605        0.002944
# 11       0.006908      0.001954         0.003060        0.002946
# 12       0.005391      0.005557         0.004958        0.004168
# 13       0.005969      0.004881         0.005556        0.005476
# 14       0.008496      0.001825         0.001878        0.002705
# 15       0.005720      0.004625         0.002824        0.004072
#
#    param_criterion param_max_features param_splitter  \
# 0   absolute_error               sqrt           best
# 1   absolute_error               sqrt         random
# 2   absolute_error               log2           best
# 3   absolute_error               log2         random
# 4          poisson               sqrt           best
# 5          poisson               sqrt         random
# 6          poisson               log2           best
# 7          poisson               log2         random
# 8    squared_error               sqrt           best
# 9    squared_error               sqrt         random
# 10   squared_error               log2           best
# 11   squared_error               log2         random
# 12    friedman_mse               sqrt           best
# 13    friedman_mse               sqrt         random
# 14    friedman_mse               log2           best
# 15    friedman_mse               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'absolute_error', 'max_features'...           0.736104
# 1   {'criterion': 'absolute_error', 'max_features'...           0.386300
# 2   {'criterion': 'absolute_error', 'max_features'...           0.568504
# 3   {'criterion': 'absolute_error', 'max_features'...           0.694926
# 4   {'criterion': 'poisson', 'max_features': 'sqrt...           0.732341
# 5   {'criterion': 'poisson', 'max_features': 'sqrt...           0.674497
# 6   {'criterion': 'poisson', 'max_features': 'log2...           0.691379
# 7   {'criterion': 'poisson', 'max_features': 'log2...           0.767341
# 8   {'criterion': 'squared_error', 'max_features':...           0.743210
# 9   {'criterion': 'squared_error', 'max_features':...           0.733268
# 10  {'criterion': 'squared_error', 'max_features':...           0.418335
# 11  {'criterion': 'squared_error', 'max_features':...           0.497975
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.684079
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.449442
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.642192
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.731520
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.614825           0.640554           0.664929
# 1            0.572958           0.683492           0.484867
# 2            0.584870           0.630594           0.622683
# 3            0.515771           0.717300           0.539359
# 4            0.659840           0.489414           0.634865
# 5            0.621520           0.520560           0.515938
# 6            0.510144           0.521871           0.622230
# 7            0.634046           0.604703           0.600593
# 8            0.712255           0.667661           0.633164
# 9            0.670172           0.611648           0.563871
# 10           0.583449           0.591414           0.396559
# 11           0.479970           0.507813           0.534301
# 12           0.582321           0.635086           0.408383
# 13           0.620516           0.517119           0.579805
# 14           0.609550           0.687287           0.504656
# 15           0.570121           0.551775           0.614371
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.559406         0.643164        0.058201                2
# 1            0.587080         0.542939        0.100511               14
# 2            0.416022         0.564535        0.077756               12
# 3            0.634102         0.620292        0.080804                5
# 4            0.517183         0.606729        0.090744                6
# 5            0.572985         0.581100        0.060554               10
# 6            0.580209         0.585166        0.066804                9
# 7            0.606409         0.642618        0.063473                3
# 8            0.484476         0.648153        0.090045                1
# 9            0.628104         0.641412        0.057167                4
# 10           0.541942         0.506340        0.082762               16
# 11           0.647770         0.533566        0.059742               15
# 12           0.521540         0.566282        0.095709               11
# 13           0.618246         0.557026        0.065520               13
# 14           0.565610         0.601859        0.062843                8
# 15           0.545054         0.602568        0.068860                7
