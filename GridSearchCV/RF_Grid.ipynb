# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(independent, dependent, test_size=0.30,random_state=0)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid = {'criterion':['absolute_error', 'poisson', 'squared_error', 'friedman_mse'],'max_features': ['sqrt','log2'],'n_estimators':[10,100]}
grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose= 3,n_jobs=-1)
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['absolute_error', 'poisson',
#                                        'squared_error', 'friedman_mse'],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
re=grid.cv_results_
grid_predictions = grid.predict(X_test)

# %%
from sklearn.metrics import r2_score
r_score=r2_score(y_test,grid_predictions)
print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter {'criterion': 'friedman_mse', 'max_features': 'log2', 'n_estimators': 100}: 0.8717274175729933

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.094345      0.003493         0.007135        0.001141
# 1        0.714720      0.016032         0.011429        0.002290
# 2        0.086558      0.007696         0.004089        0.002718
# 3        0.797472      0.024323         0.013998        0.002283
# 4        0.031074      0.003151         0.008962        0.004628
# 5        0.298791      0.019238         0.010391        0.002076
# 6        0.034483      0.005826         0.002733        0.001487
# 7        0.294691      0.011220         0.012247        0.002538
# 8        0.029709      0.003548         0.006429        0.001588
# 9        0.252999      0.009824         0.012346        0.001642
# 10       0.033484      0.003556         0.003066        0.002873
# 11       0.265975      0.022299         0.012228        0.003336
# 12       0.036880      0.007116         0.006317        0.003133
# 13       0.261237      0.008221         0.012808        0.003405
# 14       0.033140      0.005241         0.004029        0.003515
# 15       0.209675      0.012164         0.007176        0.004270
#
#    param_criterion param_max_features param_n_estimators  \
# 0   absolute_error               sqrt                 10
# 1   absolute_error               sqrt                100
# 2   absolute_error               log2                 10
# 3   absolute_error               log2                100
# 4          poisson               sqrt                 10
# 5          poisson               sqrt                100
# 6          poisson               log2                 10
# 7          poisson               log2                100
# 8    squared_error               sqrt                 10
# 9    squared_error               sqrt                100
# 10   squared_error               log2                 10
# 11   squared_error               log2                100
# 12    friedman_mse               sqrt                 10
# 13    friedman_mse               sqrt                100
# 14    friedman_mse               log2                 10
# 15    friedman_mse               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'absolute_error', 'max_features'...           0.859546
# 1   {'criterion': 'absolute_error', 'max_features'...           0.855647
# 2   {'criterion': 'absolute_error', 'max_features'...           0.825803
# 3   {'criterion': 'absolute_error', 'max_features'...           0.857027
# 4   {'criterion': 'poisson', 'max_features': 'sqrt...           0.840377
# 5   {'criterion': 'poisson', 'max_features': 'sqrt...           0.862456
# 6   {'criterion': 'poisson', 'max_features': 'log2...           0.856967
# 7   {'criterion': 'poisson', 'max_features': 'log2...           0.864015
# 8   {'criterion': 'squared_error', 'max_features':...           0.849559
# 9   {'criterion': 'squared_error', 'max_features':...           0.868321
# 10  {'criterion': 'squared_error', 'max_features':...           0.851368
# 11  {'criterion': 'squared_error', 'max_features':...           0.866990
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.864998
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.868317
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.833393
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.870920
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.775130           0.791253           0.829279
# 1            0.793192           0.805856           0.823297
# 2            0.774741           0.773216           0.788928
# 3            0.792961           0.806485           0.830691
# 4            0.744087           0.787380           0.798908
# 5            0.787240           0.802880           0.825611
# 6            0.782839           0.785198           0.801220
# 7            0.788155           0.801964           0.827381
# 8            0.787924           0.804078           0.779771
# 9            0.795739           0.808800           0.829873
# 10           0.761507           0.783069           0.788094
# 11           0.793106           0.807139           0.815139
# 12           0.766863           0.770750           0.800944
# 13           0.783094           0.806341           0.834582
# 14           0.771345           0.766916           0.797096
# 15           0.790869           0.815801           0.830294
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.743819         0.799806        0.040630                9
# 1            0.769606         0.809520        0.028950                8
# 2            0.759416         0.784421        0.022703               14
# 3            0.771010         0.811635        0.029830                3
# 4            0.750330         0.784216        0.035039               15
# 5            0.771075         0.809853        0.031872                7
# 6            0.758479         0.796941        0.032977               11
# 7            0.772398         0.810782        0.032163                5
# 8            0.765090         0.797284        0.029016               10
# 9            0.771240         0.814795        0.032828                2
# 10           0.777833         0.792374        0.030820               12
# 11           0.769991         0.810473        0.032148                6
# 12           0.731017         0.786914        0.044904               13
# 13           0.762509         0.810968        0.037398                4
# 14           0.734554         0.780661        0.033022               16
# 15           0.772242         0.816025        0.033961                1
