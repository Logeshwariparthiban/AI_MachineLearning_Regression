# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent=dataset[['charges']]

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'criterion':['absolute_error', 'poisson', 'squared_error', 'friedman_mse'],'max_features': ['sqrt','log2'],'n_estimators':[10,100]}
grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose= 3,n_jobs=-1)
grid.fit(independent, dependent)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['absolute_error', 'poisson',
#                                        'squared_error', 'friedman_mse'],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
re=grid.cv_results_
grid_predictions = grid.predict(independent)

# %%
from sklearn.metrics import r2_score
r_score=r2_score(dependent,grid_predictions)
print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter {'criterion': 'squared_error', 'max_features': 'sqrt', 'n_estimators': 100}: 0.9760930537514144

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.127923      0.009319         0.006604        0.007237
# 1        1.135356      0.047648         0.015953        0.002392
# 2        0.141842      0.022583         0.003222        0.001759
# 3        1.274821      0.077167         0.014738        0.005290
# 4        0.043774      0.007096         0.003011        0.002522
# 5        0.428690      0.097674         0.012591        0.003697
# 6        0.039238      0.004830         0.004911        0.001198
# 7        0.375216      0.016605         0.014087        0.003184
# 8        0.047021      0.003787         0.004858        0.003700
# 9        0.307988      0.015337         0.019588        0.000845
# 10       0.037124      0.001932         0.004759        0.002544
# 11       0.341785      0.004480         0.014908        0.002004
# 12       0.048174      0.004321         0.004376        0.001809
# 13       0.316496      0.013420         0.014261        0.001046
# 14       0.031703      0.002632         0.005514        0.005114
# 15       0.278082      0.007735         0.014603        0.006052
#
#    param_criterion param_max_features param_n_estimators  \
# 0   absolute_error               sqrt                 10
# 1   absolute_error               sqrt                100
# 2   absolute_error               log2                 10
# 3   absolute_error               log2                100
# 4          poisson               sqrt                 10
# 5          poisson               sqrt                100
# 6          poisson               log2                 10
# 7          poisson               log2                100
# 8    squared_error               sqrt                 10
# 9    squared_error               sqrt                100
# 10   squared_error               log2                 10
# 11   squared_error               log2                100
# 12    friedman_mse               sqrt                 10
# 13    friedman_mse               sqrt                100
# 14    friedman_mse               log2                 10
# 15    friedman_mse               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'absolute_error', 'max_features'...           0.846453
# 1   {'criterion': 'absolute_error', 'max_features'...           0.860185
# 2   {'criterion': 'absolute_error', 'max_features'...           0.829058
# 3   {'criterion': 'absolute_error', 'max_features'...           0.855920
# 4   {'criterion': 'poisson', 'max_features': 'sqrt...           0.849522
# 5   {'criterion': 'poisson', 'max_features': 'sqrt...           0.863422
# 6   {'criterion': 'poisson', 'max_features': 'log2...           0.855523
# 7   {'criterion': 'poisson', 'max_features': 'log2...           0.859018
# 8   {'criterion': 'squared_error', 'max_features':...           0.844019
# 9   {'criterion': 'squared_error', 'max_features':...           0.859406
# 10  {'criterion': 'squared_error', 'max_features':...           0.847680
# 11  {'criterion': 'squared_error', 'max_features':...           0.858694
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.845681
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.854353
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.832549
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.858350
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.759680           0.835864           0.830438
# 1            0.782055           0.854826           0.825993
# 2            0.759930           0.838581           0.811764
# 3            0.777775           0.857218           0.828638
# 4            0.769451           0.848438           0.806749
# 5            0.778166           0.860700           0.827386
# 6            0.768617           0.838400           0.802439
# 7            0.775421           0.862109           0.827292
# 8            0.762797           0.858092           0.824518
# 9            0.780751           0.858130           0.832709
# 10           0.741466           0.851042           0.807681
# 11           0.781211           0.856177           0.827678
# 12           0.767196           0.839642           0.815538
# 13           0.776974           0.857616           0.831480
# 14           0.749933           0.829360           0.803249
# 15           0.774598           0.858683           0.828931
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.832690         0.821025        0.031160                9
# 1            0.840294         0.832671        0.027973                4
# 2            0.831658         0.814198        0.028535               15
# 3            0.842642         0.832439        0.029230                6
# 4            0.816839         0.818200        0.029681               12
# 5            0.839644         0.833863        0.030892                2
# 6            0.816423         0.816280        0.029976               14
# 7            0.842590         0.833286        0.031508                3
# 8            0.809652         0.819816        0.032947               10
# 9            0.842571         0.834713        0.028760                1
# 10           0.838630         0.817300        0.040890               13
# 11           0.839252         0.832602        0.028093                5
# 12           0.825263         0.818664        0.027829               11
# 13           0.838961         0.831877        0.029094                7
# 14           0.831652         0.809349        0.031634               16
# 15           0.837069         0.831526        0.030774                8
