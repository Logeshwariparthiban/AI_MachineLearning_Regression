# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid = {'criterion':['absolute_error', 'poisson', 'squared_error', 'friedman_mse'],
 'max_features': ['sqrt','log2'],
 'splitter':['best','random']}
grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit = True, verbose= 3,n_jobs=-1)
 # fitting the model for grid search
grid.fit(independent, dependent)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['absolute_error', 'poisson',
#                                        'squared_error', 'friedman_mse'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re=grid.cv_results_
grid_predictions = grid.predict(independent)

# %%
from sklearn.metrics import r2_score
r_score=r2_score(dependent,grid_predictions)
print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter {'criterion': 'squared_error', 'max_features': 'sqrt', 'splitter': 'best'}: 0.998667156135576

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.029403      0.002489         0.003276        0.001476
# 1        0.023861      0.004449         0.007797        0.004217
# 2        0.027395      0.001915         0.003148        0.002736
# 3        0.022132      0.001811         0.004970        0.002080
# 4        0.007866      0.002186         0.002429        0.002020
# 5        0.007963      0.004448         0.000594        0.001187
# 6        0.008660      0.000859         0.003737        0.000733
# 7        0.007013      0.001390         0.002947        0.001566
# 8        0.006954      0.000375         0.002546        0.003648
# 9        0.005076      0.003343         0.004050        0.003200
# 10       0.003360      0.001162         0.005346        0.003241
# 11       0.004111      0.002275         0.005161        0.002190
# 12       0.006494      0.002987         0.003038        0.003391
# 13       0.004935      0.003291         0.004051        0.002947
# 14       0.008643      0.002751         0.000742        0.000965
# 15       0.007858      0.002656         0.000802        0.001605
#
#    param_criterion param_max_features param_splitter  \
# 0   absolute_error               sqrt           best
# 1   absolute_error               sqrt         random
# 2   absolute_error               log2           best
# 3   absolute_error               log2         random
# 4          poisson               sqrt           best
# 5          poisson               sqrt         random
# 6          poisson               log2           best
# 7          poisson               log2         random
# 8    squared_error               sqrt           best
# 9    squared_error               sqrt         random
# 10   squared_error               log2           best
# 11   squared_error               log2         random
# 12    friedman_mse               sqrt           best
# 13    friedman_mse               sqrt         random
# 14    friedman_mse               log2           best
# 15    friedman_mse               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'absolute_error', 'max_features'...           0.726618
# 1   {'criterion': 'absolute_error', 'max_features'...           0.642254
# 2   {'criterion': 'absolute_error', 'max_features'...           0.676649
# 3   {'criterion': 'absolute_error', 'max_features'...           0.765033
# 4   {'criterion': 'poisson', 'max_features': 'sqrt...           0.695101
# 5   {'criterion': 'poisson', 'max_features': 'sqrt...           0.646089
# 6   {'criterion': 'poisson', 'max_features': 'log2...           0.747980
# 7   {'criterion': 'poisson', 'max_features': 'log2...           0.618402
# 8   {'criterion': 'squared_error', 'max_features':...           0.759780
# 9   {'criterion': 'squared_error', 'max_features':...           0.692054
# 10  {'criterion': 'squared_error', 'max_features':...           0.710195
# 11  {'criterion': 'squared_error', 'max_features':...           0.674358
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.735830
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.707006
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.790170
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.619488
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.551731           0.673300           0.751254
# 1            0.612365           0.670762           0.683974
# 2            0.584108           0.631017           0.620654
# 3            0.460909           0.691311           0.642915
# 4            0.628118           0.766466           0.539318
# 5            0.641581           0.688905           0.573563
# 6            0.609601           0.592221           0.630371
# 7            0.542868           0.656215           0.737956
# 8            0.589995           0.760649           0.671080
# 9            0.443000           0.724335           0.613471
# 10           0.649763           0.649841           0.650743
# 11           0.543341           0.671330           0.694644
# 12           0.515994           0.719157           0.705542
# 13           0.488215           0.587296           0.657519
# 14           0.616604           0.548572           0.701094
# 15           0.522750           0.699277           0.687089
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.709309         0.682442        0.070110                2
# 1            0.705947         0.663060        0.032677                9
# 2            0.706172         0.643720        0.042969               12
# 3            0.730763         0.658186        0.106708               10
# 4            0.780674         0.681935        0.089782                3
# 5            0.697228         0.649473        0.043981               11
# 6            0.752897         0.666614        0.069518                7
# 7            0.625261         0.636141        0.063091               14
# 8            0.710119         0.698325        0.063683                1
# 9            0.718850         0.638342        0.105393               13
# 10           0.682761         0.668661        0.024316                6
# 11           0.733106         0.663356        0.063925                8
# 12           0.722353         0.679775        0.082455                4
# 13           0.588642         0.605736        0.074001               16
# 14           0.701037         0.671495        0.082408                5
# 15           0.581992         0.622119        0.065827               15

# %%
import pickle
filename="finilized_model_decisiontreeregression.sav"

# %%
pickle.dump(grid,open(filename,'wb'))

# %%
loaded_model=pickle.load(open("finilized_model_decisiontreeregression.sav",'rb'))

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 8
# BMI: 56
# Children: 8
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 0

# %%
Future_Prediction=loaded_model.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[4561.1885]
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
