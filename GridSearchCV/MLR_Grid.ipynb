# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(independent, dependent, test_size=0.30,random_state=0)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression
param_grid = {'fit_intercept': [True,False], 'copy_X': [True,False], 'n_jobs': [None], 'positive': [True,False]}  
grid = GridSearchCV(LinearRegression(), param_grid, refit = True, verbose= 3,n_jobs=-1)
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# GridSearchCV(estimator=LinearRegression(), n_jobs=-1,
#              param_grid={'copy_X': [True, False],
#                          'fit_intercept': [True, False], 'n_jobs': [None],
#                          'positive': [True, False]},
#              verbose=3)

# %%
re=grid.cv_results_
grid_predictions = grid.predict(X_test)

# %%
from sklearn.metrics import r2_score
r_score=r2_score(y_test,grid_predictions)
print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': True}: 0.7894429387120755

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_copy_X  \
# 0       0.053101      0.026463         0.013363        0.000545         True
# 1       0.022291      0.018388         0.001826        0.001935         True
# 2       0.003218      0.002727         0.001202        0.001472         True
# 3       0.003234      0.003961         0.004223        0.003623         True
# 4       0.005587      0.000710         0.003584        0.002974        False
# 5       0.003483      0.003835         0.002590        0.004931        False
# 6       0.007952      0.004596         0.000486        0.000972        False
# 7       0.004806      0.004881         0.005359        0.004899        False
#
#   param_fit_intercept param_n_jobs param_positive  \
# 0                True         None           True
# 1                True         None          False
# 2               False         None           True
# 3               False         None          False
# 4                True         None           True
# 5                True         None          False
# 6               False         None           True
# 7               False         None          False
#
#                                               params  split0_test_score  \
# 0  {'copy_X': True, 'fit_intercept': True, 'n_job...           0.763511
# 1  {'copy_X': True, 'fit_intercept': True, 'n_job...           0.763511
# 2  {'copy_X': True, 'fit_intercept': False, 'n_jo...           0.743115
# 3  {'copy_X': True, 'fit_intercept': False, 'n_jo...           0.744435
# 4  {'copy_X': False, 'fit_intercept': True, 'n_jo...           0.763511
# 5  {'copy_X': False, 'fit_intercept': True, 'n_jo...           0.763511
# 6  {'copy_X': False, 'fit_intercept': False, 'n_j...           0.743115
# 7  {'copy_X': False, 'fit_intercept': False, 'n_j...           0.744435
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.703146           0.730655           0.695634           0.719080
# 1           0.702938           0.730655           0.695551           0.719087
# 2           0.657160           0.699508           0.657341           0.684679
# 3           0.657009           0.700806           0.657076           0.686170
# 4           0.703146           0.730655           0.695634           0.719080
# 5           0.702938           0.730655           0.695551           0.719087
# 6           0.657160           0.699508           0.657341           0.684679
# 7           0.657009           0.700806           0.657076           0.686170
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.722405        0.023902                1
# 1         0.722348        0.023954                3
# 2         0.688361        0.031848                7
# 3         0.689099        0.032444                5
# 4         0.722405        0.023902                1
# 5         0.722348        0.023954                3
# 6         0.688361        0.031848                7
# 7         0.689099        0.032444                5
